# %%
import pandas as pd
import numpy as np

# %%
print('Hello world!')
# Out:
# Hello world!

# %%
# 1) Import data set and store it in a variable called df
import pandas as pd
df=pd.read_csv('data/option_GS_df.csv')
df.head()
# 2) Show the shape of the data frame (number of rows, number of columns)
# 3) How many call and put options do we have in this data set?
# 4) What's the maximum and minimum and mean values of UnderlyingPrice and Strike ?
# 5) what's the min and max of dates: Expiration and DataDate?
# Out:
#    Unnamed: 0  UnderlyingPrice       OptionSymbol  Type  Expiration  \
# 0           0           174.09  GS160108C00125000  call  01/08/2016
# 1           1           174.09  GS160108P00125000   put  01/08/2016
# 2           2           174.09  GS160108C00130000  call  01/08/2016
# 3           3           174.09  GS160108P00130000   put  01/08/2016
# 4           4           174.09  GS160108C00135000  call  01/08/2016
#
#      DataDate  Strike  Last    Bid    Ask  ...  OpenInterest  T1OpenInterest  \
# 0  01/05/2016   125.0   0.0  46.95  50.80  ...             0               0
# 1  01/05/2016   125.0   0.0   0.00   0.31  ...             0               0
# 2  01/05/2016   130.0   0.0  41.80  45.80  ...             0               0
# 3  01/05/2016   130.0   0.0   0.00   0.31  ...             0               0
# 4  01/05/2016   135.0   0.0  36.95  40.90  ...             0               0
#
#    IVMean  IVBid   IVAsk   Delta   Gamma   Theta    Vega                AKA
# ...

# %%
df = pd.read_csv('data/option_GS_df.csv')
df.head()
# Out:
#    Unnamed: 0  UnderlyingPrice       OptionSymbol  Type  Expiration  \
# 0           0           174.09  GS160108C00125000  call  01/08/2016
# 1           1           174.09  GS160108P00125000   put  01/08/2016
# 2           2           174.09  GS160108C00130000  call  01/08/2016
# 3           3           174.09  GS160108P00130000   put  01/08/2016
# 4           4           174.09  GS160108C00135000  call  01/08/2016
#
#      DataDate  Strike  Last    Bid    Ask  ...  OpenInterest  T1OpenInterest  \
# 0  01/05/2016   125.0   0.0  46.95  50.80  ...             0               0
# 1  01/05/2016   125.0   0.0   0.00   0.31  ...             0               0
# 2  01/05/2016   130.0   0.0  41.80  45.80  ...             0               0
# 3  01/05/2016   130.0   0.0   0.00   0.31  ...             0               0
# 4  01/05/2016   135.0   0.0  36.95  40.90  ...             0               0
#
#    IVMean  IVBid   IVAsk   Delta   Gamma   Theta    Vega                AKA
# ...
